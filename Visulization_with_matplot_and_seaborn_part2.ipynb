# %% [markdown]
# <a href="https://colab.research.google.com/github/FSMahi/Python-for-Data-analysis/blob/main/Visulization_with_matplot_and_seaborn_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Scatter Plot**

# %%
import pandas as pd
import matplotlib
#load data into a pandas dataframe
flower_df= sns.load_dataset('iris')

# %%
flower_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flower_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flower_df.sepal_length,flower_df.sepal_width);

# %%
plt.scatter(flower_df.sepal_length,flower_df.sepal_width);

# %%
sns.set_style('darkgrid')
sns.scatterplot(x='sepal_length', y='sepal_width', data=flower_df);

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=flower_df, hue = flower_df.species,s=100);

# %% [markdown]
# Customizing seaborn figure

# %%
plt.figure(figsize=(10,6))
plt.title('Sepal Dimensions')
sns.scatterplot(x='sepal_length', y='sepal_width', data=flower_df, hue = flower_df.species,s=100);

# %% [markdown]
# Plot using pandas dataframe

# %%
plt.title('Sepal Dimensions')
sns.scatterplot(x= 'sepal_length',
                y= 'sepal_width',
                data=flower_df,
                hue = 'species',
                s=100);

# %% [markdown]
# **Histogram**

# %%
flower_df = sns.load_dataset('iris')

# %%
flower_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
flower_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.title('Distribution of Sepal Width')
sns.histplot(flower_df.sepal_width);

# %% [markdown]
# Controlling the size and number of bins

# %%
plt.hist(flower_df.sepal_width, bins=5);

# %%
import numpy as np
np.arange(2, 5, 0.25)
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#        4.75])

# %%
plt.hist(flower_df.sepal_width, bins=np.arange(2, 5, 0.25));

# %%
plt.hist(flower_df.sepal_width, bins=np.arange(2, 5, 0.25), edgecolor='black');

# %%
plt.hist(flower_df.sepal_width,bins=[1,3,4,4.5]);

# %% [markdown]
# Multiple Histogram

# %%
setosa_df = flower_df[flower_df.species == 'setosa']
versicolor_df = flower_df[flower_df.species == 'versicolor']
virginica_df = flower_df[flower_df.species == 'virginica']

# %%
setosa_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
plt.hist(setosa_df.sepal_width, bins=np.arange(2,5,.25), alpha=0.4, label='Setosa');
plt.hist(versicolor_df.sepal_width, bins=np.arange(2,5,.25), alpha=0.4, label='Versicolor');
plt.legend(['setosa','versicolor']);

# %%
plt.hist(setosa_df.sepal_width, bins=np.arange(2,5,.25), alpha=0.5, label='Setosa');
plt.hist(versicolor_df.sepal_width, bins=np.arange(2,5,.25), alpha=0.4, label='Versicolor');
plt.hist(virginica_df.sepal_width, bins=np.arange(2,5,.25), alpha=0.5, label='Virginica');
plt.legend(['setosa','versicolor','virginica']);

# %%
plt.title('Distribution of Sepal Width')
plt.hist([setosa_df.sepal_width,versicolor_df.sepal_width,virginica_df.sepal_width], bins=np.arange(2,5,.25),  stacked=True);
plt.legend(['setosa','versicolor','virginica']);

# %% [markdown]
# **Bar chart**

# %%
years= range(2000,2006)
apples = [0.35, 0.6, 0.9, 0.926, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.plot(years,apples);

# %%
plt.bar(years,apples);

# %%
plt.bar(years,apples, label='Apples');
plt.bar(years,oranges, label='Oranges');
plt.legend();

# %%
plt.bar(years,apples);
plt.plot(years,apples, 'o--r');
plt.title('Apples');

# %%
plt.bar(years,apples, label='Apples');
plt.bar(years,oranges, label='Oranges', bottom= apples);
plt.legend();

# %% [markdown]
# Bar chat with averages

# %%
tips_df= sns.load_dataset('tips')

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
bill_avg = tips_df.groupby('day')[['total_bill']].mean()
bill_avg
# Out:
# <ipython-input-31-1673dca293c0>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bill_avg = tips_df.groupby('day')[['total_bill']].mean()
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(bill_avg.index, bill_avg.total_bill);

# %%
sns.barplot(x='day', y='total_bill', data=tips_df);

# %%
sns.barplot(x='day', y='total_bill', data=tips_df, hue='sex');

# %%
sns.barplot(x='day', y='total_bill', data=tips_df, hue='smoker');

# %%
sns.barplot(x='total_bill', y='day', data=tips_df, hue='smoker');

# %%
df_flight= sns.load_dataset('flights')
df_flight
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.plot( df_flight.passengers);

# %% [markdown]
# # Heatmap

# %%
flights_df = df_flight.pivot(index='month', columns='year', values='passengers')
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title('No. of Passengers');
sns.heatmap(flights_df);

# %%
plt.title('No. of Passengers');
sns.heatmap(flights_df,fmt='d' ,annot=True,cmap='Blues');

# %%
from urllib.request import urlretrieve
urlretrieve("https://images.twinkl.co.uk/tw1n/image/private/t_630/u/ux/barchart_ver_2.jpg",'Chart.jpg')
# Out:
# ('Chart.jpg', <http.client.HTTPMessage at 0x7e0b3c4a8ad0>)

# %%
from PIL import Image
img= Image.open('Chart.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=630x538>

# %%
img_arr= np.array(img)
img_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img_arr.shape
# Out:
# (538, 630, 3)

# %%
plt.imshow(img);

# %%
plt.title('Graph');
plt.grid(False);
plt.axis('off');
plt.imshow(img_arr);

# %%
plt.grid(False);
plt.axis('off');
plt.imshow(img_arr[125:352,105:305]);

# %%
yield_apple = [0.895, 0.91,0.919,0.926,0.929,0.931,0.934,0.936,0.941,0.955,0.962,0.98]
yield_orange = [0.962,0.967,0.93,0.91,0.94,0.97,0.91,0.93,0.98,0.91,0.95,0.99]

# %%
fig, axes =plt.subplots(2,3 , figsize= (12,9))

#uses axes for ploting
axes[0,0].plot(years,apples,'s-b')
axes[0,0].plot(years,oranges,'o--r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield (tons per hectare)')
axes[0,0].set_title('Crop Yeilds')
axes[0,0].legend(['Apples','Oranges'])

#pass the axes in the seaborn
axes[0,1].set_title('Sepal length vs Sepal width')
sns.scatterplot(x='sepal_length', y='sepal_width', data=flower_df, hue=flower_df.species, s=100 ,ax=axes[0,1])

#use the axes for plotting
axes[0,2].set_title('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width,versicolor_df.sepal_width, virginica_df.sepal_width], bins=np.arange(2,5,.25), edgecolor='black', stacked= True)
axes[0,2].legend(['Setosa','Versicolor','Virginica'])

#pass the axes into seaborn
axes[1,0].set_title('Restaurant Bills')
sns.barplot(x='day', y='total_bill', data=tips_df, hue='sex', ax=axes[1,0])

#pass the axes into seaborn
axes[1,1].set_title('Flight Traffic')
sns.heatmap(flights_df, cmap='Blues', ax=axes[1,1])

#plot an image use an axes
axes[1,2].set_title('Graph Chart')
plt.imshow(img)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])

plt.tight_layout(pad=2)

# %%
axes.shape
# Out:
# (2, 3)

# %%
axes[0,0]
# Out:
# <Axes: >
